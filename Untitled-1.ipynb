# %%
import os
data_yaml = """
path: "C:/Users/avika/Downloads/dataset/images"
train: "C:/Users/avika/Downloads/dataset/images/train"
val: "C:/Users/avika/Downloads/dataset/images/val"

names:
  0: weed
  1: crop
"""

with open("data.yaml", "w") as f:
    f.write(data_yaml)

print("data.yaml created")
# Out:
# data.yaml created

# %%
from ultralytics import YOLO
def model():
    model = YOLO('yolov8n.pt')  

    model.train(data="data.yaml", epochs=10, imgsz=419, batch = 8 ,workers = 4,cache=True, name="yolo_weed_detection", exist_ok=True,amp = True)
    
if __name__ == "__main__":
    model()
# Out:
# Ultralytics 8.4.14  Python-3.13.12 torch-2.10.0+cpu CPU (AMD Ryzen 7 7445HS w/ Radeon 740M Graphics)
# ...

# %%
import torch
import torch.nn as nn
import torch.functional as F

class model(nn.Module):
    def __init__(self):
        super(model, self).__init__()
        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.fc1 = nn.Linear(32 * 16 * 16, 128)
        self.fc2 = nn.Linear(128, 10)   
    def forward(self,x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 32 * 16 * 16)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x
    model = model()
    print(model)
# Out:
# model(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=8192, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=10, bias=True)
# )
